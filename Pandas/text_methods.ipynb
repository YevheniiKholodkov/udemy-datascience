# %%
import pandas as pd
import numpy as np

# %%
email = 'jose@email.com'

# %%
email.split('@')
# Out:
# ['jose', 'email.com']

# %%
names = pd.Series(['andreq', 'bobo', 'claire', 'david', '5'])

# %%
names
# Out:
# 0    andreq
# 1      bobo
# 2    claire
# 3     david
# 4         5
# dtype: object

# %%
names.str.upper()
# Out:
# 0    ANDREQ
# 1      BOBO
# 2    CLAIRE
# 3     DAVID
# 4         5
# dtype: object

# %%
names.str

# %%
names.str.isdigit()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
tech_finance = ['GOOG,APPL,AMZN', 'JPM,BAC,GS']

# %%
tickers = pd.Series(tech_finance)

# %%
tickers.str.split(',', expand=True)
# Out:
#       0     1     2
# 0  GOOG  APPL  AMZN
# 1   JPM   BAC    GS

# %%
tech = 'GOOG,APPL,AMZN'

# %%
tech.split(',')[0]
# Out:
# 'GOOG'

# %%
messy_names = pd.Series(['andrew  ', "bo;bo", "    claire "])

# %%
messy_names
# Out:
# 0       andrew
# 1          bo;bo
# 2        claire
# dtype: object

# %%
messy_names.str.replace(';', '').str.strip().str.capitalize()
# Out:
# 0    Andrew
# 1      Bobo
# 2    Claire
# dtype: object
